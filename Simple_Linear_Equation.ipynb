# %% [markdown]
# <a href="https://colab.research.google.com/github/GunavathiC/ML_Algorithms/blob/main/Simple_Linear_Equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/content/appliance_energy.csv')

# %%
df
# Out:
#     Temperature (°C)  Energy Consumption (kWh)
# 0          22.490802                  2.292604
# 1          34.014286                  3.251925
# 2          29.639879                  3.009868
# 3          26.973170                  1.703533
# 4          18.120373                  1.702201
# ..               ...                       ...
# 95         24.875912                  2.079686
# 96         25.454657                  2.506915
# 97         23.550820                  2.525658
# 98         15.508383                  1.689184
# 99         17.157829                  2.129374
#
# [100 rows x 2 columns]

# %%
print(df.head())
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Temperature (°C)          100 non-null    float64
#  1   Energy Consumption (kWh)  100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB
# None

# %%
print(df.tail())
# Out:
#     Temperature (°C)  Energy Consumption (kWh)
# 95         24.875912                  2.079686
# 96         25.454657                  2.506915
# 97         23.550820                  2.525658
# 98         15.508383                  1.689184
# 99         17.157829                  2.129374

# %% [markdown]
# **Data cleaning**

# %%
df.describe()
# Out:
#        Temperature (°C)  Energy Consumption (kWh)
# count        100.000000                100.000000
# mean          24.403615                  2.439821
# std            5.949788                  0.693527
# min           15.110442                  0.978107
# 25%           18.864015                  1.908640
# 50%           24.282849                  2.364121
# 75%           29.604062                  2.931199
# max           34.737739                  4.159094

# %%
df.isnull().sum()
# Out:
# Temperature (°C)            0
# Energy Consumption (kWh)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df= df.dropna()

# %%
df.isnull().sum()
df= df.dropna()

# %%
X = df['Temperature (°C)']
Y = df['Energy Consumption (kWh)']

# %%
X
# Out:
# 0     22.490802
# 1     34.014286
# 2     29.639879
# 3     26.973170
# 4     18.120373
#         ...
# 95    24.875912
# 96    25.454657
# 97    23.550820
# 98    15.508383
# 99    17.157829
# Name: Temperature (°C), Length: 100, dtype: float64

# %%
Y
# Out:
# 0     2.292604
# 1     3.251925
# 2     3.009868
# 3     1.703533
# 4     1.702201
#         ...
# 95    2.079686
# 96    2.506915
# 97    2.525658
# 98    1.689184
# 99    2.129374
# Name: Energy Consumption (kWh), Length: 100, dtype: float64

# %% [markdown]
# **Training and Testin**g

# %%
#testing sets
train_test_split(X,Y, test_size=0.2, random_state=42)
# Out:
# [55    33.437485
#  88    32.744255
#  26    18.993476
#  42    15.687770
#  69    34.737739
#          ...
#  60    22.773546
#  71    18.974314
#  14    18.636499
#  92    30.215701
#  51    30.502656
#  Name: Temperature (°C), Length: 80, dtype: float64,
#  83    16.271167
#  53    32.896547
#  70    30.444895
#  45    28.250446
#  44    20.175600
#  39    23.803050
#  22    20.842893
#  80    32.262069
#  10    15.411690
#  0     22.490802
#  18    23.638900
#  30    27.150897
#  73    31.309229
#  33    33.977711
#  90    17.391885
#  4     18.120373
#  76    30.425407
#  77    16.480893
#  12    31.648853
#  31    18.410482
#  Name: Temperature (°C), dtype: float64,
#  55    3.378030
#  88    3.756114
#  26    1.727990
#  42    2.140188
#  69    3.864685
#          ...
#  60    1.885728
#  71    1.237203
#  14    1.912189
#  92    2.898876
#  51    2.767117
#  Name: Energy Consumption (kWh), Length: 80, dtype: float64,
#  83    1.955394
#  53    3.037917
#  70    2.426014
# ...

# %%
#split data into training and testing sets
X_train, X_test , Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
# 55    33.437485
# 88    32.744255
# 26    18.993476
# 42    15.687770
# 69    34.737739
#         ...
# 60    22.773546
# 71    18.974314
# 14    18.636499
# 92    30.215701
# 51    30.502656
# Name: Temperature (°C), Length: 80, dtype: float64

# %%
Y_train
# Out:
# 55    3.378030
# 88    3.756114
# 26    1.727990
# 42    2.140188
# 69    3.864685
#         ...
# 60    1.885728
# 71    1.237203
# 14    1.912189
# 92    2.898876
# 51    2.767117
# Name: Energy Consumption (kWh), Length: 80, dtype: float64

# %%
#create a linear regression model
model = LinearRegression()
#training model
model.fit(X_train.values.reshape(-1, 1), Y_train)
# Out:
# LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test.values.reshape(-1, 1))

# %%
Y_pred
# Out:
# array([1.6858187 , 3.18154068, 2.96097494, 2.76354868, 2.0370856 ,
#        2.36343345, 2.09711944, 3.12445907, 1.60849483, 2.24537556,
#        2.34866555, 2.66462648, 3.0387357 , 3.27880886, 1.78664542,
#        1.85218469, 2.95922164, 1.70468695, 3.0692904 , 1.87828475])

# %%
mse = mean_squared_error(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
r2 = r2_score(Y_test, Y_pred)
print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error: 0.16342487833777786
# R-Squared: 0.6119478447399157

# %%
plt.scatter(X_test, Y_test, color='blue', label='Test Data')
plt.plot(X_test, Y_pred, color='red', label='Regression Line')
plt.xlabel('Temperature (°C)')
plt.ylabel('Energy Consumption (kWh)')
plt.title('Temperature vs Energy Consumption')
plt.legend()
plt.show()
