# %% [markdown]
# <a href="https://colab.research.google.com/github/GunavathiC/ML_Algorithms/blob/main/TSNE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# %%
print("t-SNE transformation completed")
print(f"Original shape:{X.shape}")
print(f"t-SNE shape:{X_tsne.shape}")
# Out:
# t-SNE transformation completed
# Original shape:(150, 4)
# t-SNE shape:(150, 2)

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.colorbar(scatter)
plt.title('t-SNE Visualization of Iris Dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
