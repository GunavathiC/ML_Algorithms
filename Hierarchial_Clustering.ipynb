# %% [markdown]
# <a href="https://colab.research.google.com/github/GunavathiC/ML_Algorithms/blob/main/Hierarchial_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris
from scipy.cluster.hierarchy import dendrogram,linkage,fcluster

# %%
iris = load_iris()
df = pd.DataFrame(iris.data,columns=iris.feature_names)
print("First 5 rows of dataset:")
print(df.head())
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
Z = linkage(df,method='ward')

# %%
plt.figure(figsize=(10,6))
dendrogram(Z,truncate_mode="level",p=5)
plt.title("Hierarchical Clustering Dendrogram (Iris Dataset)")
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.show()

# %%
clusters = fcluster(Z,t=3,criterion='maxclust')
df['Cluster'] = clusters

# %%
plt.figure(figsize=(8,6))
plt.scatter(df.iloc[:,0],df.iloc[:,1],c=df['Cluster'],cmap='rainbow')
plt.title("Cluster formed using Hierarchical Clusteringn")
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.show()
